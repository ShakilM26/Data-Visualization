# %% [markdown]
# <a href="https://colab.research.google.com/github/ShakilM26/Some_Visualisation/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = [2,5,6,7,8]
y = [3,7,4,12,5]

plt.plot(x,y, linestyle='dotted', linewidth=6, marker='D', alpha=0.4)
plt.title('Line Graph')
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
plt.plot(x,y, '*')
plt.grid()

# %%
x=[2,4,6,8,9]
y=[1,4,6,7,8]

x2=[2,3,4,5,6]
y2=[7,8,9,10,2]

# %%
plt.plot(x,y, linewidth=3)
plt.plot(x2,y2)

# %%
x=[2,5,6,7,8]
y=[3,7,4,12,5]

x2=[4,5,8,9,8]
y2=[3,5,7,12,6]

# %%
plt.barh(x,y,color='g', linewidth=4)
plt.barh(x2,y2,color='r', linewidth=8)
plt.title('Horizontal Bar')
plt.legend(['Line1', 'Line2'], loc=4)
plt.show()

# %%
# Bubble
import numpy as np
x=[2,5,6,7,8]
y=[3,7,4,12,5]
plt.scatter(x,y, s=np.random.rand(5)*1000)
plt.show()

# %%
values=[30,44,33,23]
language=['Python', 'C', 'C++', 'Java']

plt.bar(range(4), values)
plt.xticks(range(4), language)
plt.title('Bar Graph')
plt.show()

# %%
w=0.4
sub=['Algo', 'DS', 'Database', 'SE', 'OS']

boys=[100,60,50,55,30]
girls=[90,30,40,60,60]

# %%
bar = np.arange(len(sub))
bar1 = [i+w for i in bar]

plt.bar(bar, boys, w, label='boys')
plt.bar(bar1, girls, w, label='girls')
plt.xlabel('Courses', fontweight='bold')
plt.ylabel('Students', fontweight='bold')
plt.xticks(bar+w/2,sub)
plt.legend()
plt.show()
