# %% [markdown]
# <a href="https://colab.research.google.com/github/ShakilM26/Some_Visualisation/blob/main/seaborn/seaborn_with_csvfile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = np.arange(15).reshape((3,5))
indexs = ['Rainfall', 'Humidity', 'Wind']

w = pd.DataFrame(data, index=indexs, columns=['Dhaka','Rajshahi','Sylhet','Chittagong','Mymensingh'])

w
# Out:
#           Dhaka  Rajshahi  Sylhet  Chittagong  Mymensingh
# Rainfall      0         1       2           3           4
# Humidity      5         6       7           8           9
# Wind         10        11      12          13          14

# %%
w.hist(figsize=(10,9))
plt.show()

# %%
df = pd.read_csv('d.csv')
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.set_index('Date', inplace=True)

# %%
# Univariate analysis

sns.displot(df['Rating'], kde=True)
plt.axvline(x=np.mean(df['Rating']), c='green', ls='--', label='Mean')
plt.axvline(x=np.percentile(df['Rating'], 25), c='red', ls='--', label='25th percent')
plt.axvline(x=np.percentile(df['Rating'], 75), c='red', ls='--', label='25th percent')

plt.legend()
plt.show()

# %%
df.hist(figsize=(14,10))
plt.show()

# %%
# Corr

corr = df.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))

cmap=sns.diverging_palette(230,20, as_cmap=True) 
sns.heatmap(np.round(df.corr(), 3), annot=True, cmap=cmap, mask=mask)
